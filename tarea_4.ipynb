# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuho12313/Clase1358FES/blob/main/tarea_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
archivo3 = open('junio.dat','rt', encoding= 'latin-1')
info = archivo3.readlines()

for index in range( len(info) ):
    info[index] = info[index].rstrip('\n').split(',')
    print(info[index])

print("Sueldos")
total = 0

for trab in info[1:]:
 numero = int(trab[5])
 
 total = numero + total
 
totalpro = total/14
print(totalpro)

elmasreciente = 1

for trab in info[1:]:
    
    anio = int(trab[6])
    antiguedad = 2021 - anio

    if antiguedad > elmasantiguo:
      elmasantiguo = antiguedad
    
    if antiguedad < elmasreciente:
      elmasreciente = antiguedad

print(f"Los/El/Ella trabajador/es/a mas antiguo/s es de {elmasantiguo} años")
print(f"Los/El/Ella trabajador/es/a mas reciente es de {elmasreciente} años")
# Out:
# ['numero de trabajador', ' nombres', ' paterno', ' materno', ' horas extra', ' sueldo base', ' aÃ±o de ingreso']
# ['2345', 'CARLOS', 'PEREZ', 'CASTILLO', '0', '9850', '2017']
# ['5754', 'ANGEL', 'GOMEZ', 'GARRIDO', '1', '9850', '2020']
# ['5345', 'JESUS', 'MARTIN', 'SANTOS', '2', '9850', '2016']
# ['3267', 'DAVID', 'JIMENEZ', 'LOZANO', '2', '9850', '2017']
# ['8765', 'PEDRO', 'RUIZ', 'GUERRERO', '2', '9850', '2017']
# ['5454', 'DANIEL', 'HERNANDEZ', 'CANO', '3', '9850', '2018']
# ['3456', 'ALEJANDRO', 'DIAZ', 'PRIETO', '2', '9850', '2018']
# ['3445', 'MARIA', 'MORENO', 'MENDEZ', '1', '9850', '2018']
# ['9088', 'ALBERTO', 'MU\x84OZ', 'CRUZ', '1', '9850', '2017']
# ['8877', 'RAFAEL', 'ALVAREZ', 'FLORES', '2', '9850', '2017']
# ['6767', 'FERNANDO', 'ROMERO', 'HERRERA', '4', '9850', '2019']
# ['5654', 'PABLO', 'ALONSO', 'GALLEGO', '1', '9850', '2019']
# ['4323', 'JORGE', 'GUTIERREZ', 'MARQUEZ', '2', '9850', '2020']
# ['2232', 'RAMON', 'NAVARRO', 'LEON', '1', '9850', '2016']
# Sueldos
# ...

# %%
archivo3 = open('junio.dat','rt', encoding= 'latin-1')

info = archivo3.readlines()

for index in range( len(info) ):
    info[index] = info[index].rstrip('\n').split(',')
    print(info[index])

print("Estos son los empreados disponibles")

empleados = Array(15)


empleados.set_item(1 , 2345)
empleados.set_item(2 , 5754)
empleados.set_item(3 , 5345)
empleados.set_item(4 , 3267)
empleados.set_item(5 , 8765)
empleados.set_item(6 , 5454)
empleados.set_item(7 , 3456)
empleados.set_item(8 , 3445)
empleados.set_item(9 , 9088)
empleados.set_item(10 , 8877)
empleados.set_item(11 , 6767)
empleados.set_item(12 , 5654)
empleados.set_item(13 , 4323)
empleados.set_item(14 , 2232)



valor_a_buscar = int (input("¿Que empleado buscas?"))
encontrado = False

for indice in range( empleados.get_Length()):
  if valor_a_buscar == empleados.get_item( indice ):
    print("                                     ", info[0])
    print("El empleado que usted busca es este: ", info[indice])
    encontrado = True
    break

if encontrado:
  print("El empleado si exsite")
else:
  print("El empleado no existe")
# Out:
# ['numero de trabajador', ' nombres', ' paterno', ' materno', ' horas extra', ' sueldo base', ' aÃ±o de ingreso']
# ['2345', 'CARLOS', 'PEREZ', 'CASTILLO', '0', '9850', '2017']
# ['5754', 'ANGEL', 'GOMEZ', 'GARRIDO', '1', '9850', '2020']
# ['5345', 'JESUS', 'MARTIN', 'SANTOS', '2', '9850', '2016']
# ['3267', 'DAVID', 'JIMENEZ', 'LOZANO', '2', '9850', '2017']
# ['8765', 'PEDRO', 'RUIZ', 'GUERRERO', '2', '9850', '2017']
# ['5454', 'DANIEL', 'HERNANDEZ', 'CANO', '3', '9850', '2018']
# ['3456', 'ALEJANDRO', 'DIAZ', 'PRIETO', '2', '9850', '2018']
# ['3445', 'MARIA', 'MORENO', 'MENDEZ', '1', '9850', '2018']
# ['9088', 'ALBERTO', 'MU\x84OZ', 'CRUZ', '1', '9850', '2017']
# ['8877', 'RAFAEL', 'ALVAREZ', 'FLORES', '2', '9850', '2017']
# ['6767', 'FERNANDO', 'ROMERO', 'HERRERA', '4', '9850', '2019']
# ['5654', 'PABLO', 'ALONSO', 'GALLEGO', '1', '9850', '2019']
# ['4323', 'JORGE', 'GUTIERREZ', 'MARQUEZ', '2', '9850', '2020']
# ['2232', 'RAMON', 'NAVARRO', 'LEON', '1', '9850', '2016']
# ...

# %%
lista = Array(10)

lista.set_item( 0, 15)
lista.set_item( 1, 19)
lista.set_item( 2, 65)
lista.set_item( 3, 100)
lista.set_item( 4, 23)
lista.set_item( 5, 43)
lista.set_item( 6, 10)
lista.set_item( 7, 20)
lista.set_item( 8, 78)
lista.set_item( 9, 89)

# %%
#Metodos de busqueda y ordenamiento

valor_a_buscar = int (input("¿Que valor quieres buscar?"))
encontrado = False

for indice in range( lista.get_Length()):
  if valor_a_buscar == lista.get_item( indice ):
    print("El elemento se encuentra en la posicion: ", indice)
    encontrado = True
    break

if encontrado:
  print("El elemento si exsite en el arreglo")
else:
  print("El elemento no esta en el arreglo")
# Out:
# ¿Que valor quieres buscar?100
# El elemento se encuentra en la posicion:  3
# El elemento si exsite en el arreglo

# %%
#Tarea 4: crear un programa para sacar datos de trabajadores
#13/9-17/9
#JCRS


# !cat junio.dat

# %%
archivo = open('junio.dat','rt', encoding= 'latin-1')
print( archivo.read() )


print("Probrando readline()")

archivo2 = open('junio.dat','rt', encoding= 'latin-1')
print( archivo2.readline () )
print( archivo2.readline () )

archivo3 = open('junio.dat','rt', encoding= 'latin-1')
print("Probando readlines()")
#print( archivo3.readlines () )

info = archivo3.readlines()

for index in range( len(info) ):
    info[index] = info[index].rstrip('\n').split(',')
    print(info[index])


#print(info)
#print("Sueldos")
for trab in info:
    print(trab[5])
# Out:
# numero de trabajador, nombres, paterno, materno, horas extra, sueldo base, aÃ±o de ingreso
# 2345,CARLOS,PEREZ,CASTILLO,0,9850,2017
# 5754,ANGEL,GOMEZ,GARRIDO,1,9850,2020
# 5345,JESUS,MARTIN,SANTOS,2,9850,2016
# 3267,DAVID,JIMENEZ,LOZANO,2,9850,2017
# 8765,PEDRO,RUIZ,GUERRERO,2,9850,2017
# 5454,DANIEL,HERNANDEZ,CANO,3,9850,2018
# 3456,ALEJANDRO,DIAZ,PRIETO,2,9850,2018
# 3445,MARIA,MORENO,MENDEZ,1,9850,2018
# 9088,ALBERTO,MUOZ,CRUZ,1,9850,2017
# 8877,RAFAEL,ALVAREZ,FLORES,2,9850,2017
# 6767,FERNANDO,ROMERO,HERRERA,4,9850,2019
# 5654,PABLO,ALONSO,GALLEGO,1,9850,2019
# 4323,JORGE,GUTIERREZ,MARQUEZ,2,9850,2020
# 2232,RAMON,NAVARRO,LEON,1,9850,2016
# Probrando readline()
# numero de trabajador, nombres, paterno, materno, horas extra, sueldo base, aÃ±o de ingreso
#
# 2345,CARLOS,PEREZ,CASTILLO,0,9850,2017
#
# Probando readlines()
# ['numero de trabajador', ' nombres', ' paterno', ' materno', ' horas extra', ' sueldo base', ' aÃ±o de ingreso']
# ...

# %%
#Tarea 2: Crear un ADTArray, para proximos programas
#8/9
#JCRS


class Array( ):
  def __init__( self, tamanio ):
    self.__tamanio = tamanio
    self.__data = [ 0 for x in range(self.__tamanio) ] #generador

  def get_item( self, index):
    return self.__data[index]

  def to_string(self):
    print(self.__data) 

  def set_item(self, index, dato):
    if self.__check_limit__(index):
        self.__data[index] = dato
    else:
      raise Exception("Error de limites de index")
  
  def clear(self, data):
    self.__data=[valor for x in range(self.__tamanio)]
  
  def get_Length(self):
   return self.__tamanio

  def __check_limit__(self, index):
    return index >= 0 and index < self.__tamanio

# %%
class Trabajador:
  def __init__( self, No_de_trabajador, Nombre, pater, mater, Horas_extra, Sueldo, anio_de_ingreso):
    self.num_trabajador = No_de_trabajador
    self.nombre = Nombre
    self.paterno = pater
    self.mat = mater
    self.horas_extra = Horas_extra
    self.sueldo = Sueldo
    self.anio_ingreso = anio_de_ingreso

  #gettenrs and setters

  def set_No_de_trabajador( self , No_de_trabajador):
    self.num_trabajador

  def get_No_de_trabajador( self ):
    return self.num_trabajador

  def set_Nombre( self, Nombre):
    self.nombre

  def get_Nombre(self):
    return self.nombre

  def set_paterno( self, pater):
    self.pater
  
  def get_paterno( self ):
    return self.pater

  def set_materno( self, mater):
    self.mat

  def get_materno( self ):
    return self.mat

  def set_horas_extras( self, Horas_extra ):
    self.horas_extra

  def get_horas_extras( self ):
    return self.horas_extra

  def set_sueldo( self, Sueldo):
    self.sueldo

  def get_sueldo( self ):
    return self.sueldo

  def set_anio_ingreso( self, anio_de_ingreso):
    self.anio_ingreso

  def get_anio_ingreso( self ):
    return self.anio_ingreso 
  
    # poner metodos de uso general

  def mostrar_sueldos( self, Sueldo):
    pritn(sueldo)

# %%
class Empresa:
  def __init__( self):
    # codigo para leer el archivo, podria ser un metodo local
    archivo = open('junio.dat','rt', encoding= 'latin-1')
    info = archivo

    for index in range( len(info) ):
      info[ index ] = info[ index ].rstrip( '\n' ).split( ',' )
      print(info[index])

    
    self.empleados = Array(15)
    # codigo para crear un objeto por cada linea leida del archivo y meterlo al array.

    print("Estos son los empreados disponibles")

    empleados = Array(15)


    empleados.set_item(1 , 2345)
    empleados.set_item(2 , 5754)
    empleados.set_item(3 , 5345)
    empleados.set_item(4 , 3267)
    empleados.set_item(5 , 8765)
    empleados.set_item(6 , 5454)
    empleados.set_item(7 , 3456)
    empleados.set_item(8 , 3445)
    empleados.set_item(9 , 9088)
    empleados.set_item(10 , 8877)
    empleados.set_item(11 , 6767)
    empleados.set_item(12 , 5654)
    empleados.set_item(13 , 4323)
    empleados.set_item(14 , 2232)



    valor_a_buscar = int (input("¿Que empleado buscas?"))
    encontrado = False

    for indice in range( empleados.get_Length()):
      if valor_a_buscar == empleados.get_item( indice ):
        print("                                     ", info[0])
        print("El empleado que usted busca es este: ", info[indice])
        encontrado = True
        break

    if encontrado:
      print("El empleado si exsite")
    else:
      print("El empleado no existe")

    


  def calcular_sueldos( self ):
    # codigo para recorrer self.empleados y mostrar lo que se pide los sueldos con las reglas
    
    print("Sueldos")
    total = 0

    for trab in info[1:]:
      numero = int(trab[5])
 
      total = numero + total
 
    totalpro = total/14
    print(totalpro)


  def encontrar_mayor_ant( self ):
    # codigo para calcular al mas antiguo y mostrar lo en pantalla
    # codigo para calcular al mas reciente empreado y mostrar lo en pantalla
    elmasreciente = 1

    for trab in info[1:]:
    
      anio = int(trab[6])
      antiguedad = 2021 - anio

      if antiguedad > elmasantiguo:
        elmasantiguo = antiguedad
    
      if antiguedad < elmasreciente:
        elmasreciente = antiguedad

    print(f"Los/El/Ella trabajador/es/a mas antiguo/s es de {elmasantiguo} años")
    print(f"Los/El/Ella trabajador/es/a mas reciente es de {elmasreciente} años")
